# %%
import pandas as pd

df = pd.read_csv('data/v1_biophysical_nodes.csv')
target_layers = ['VisL4', 'VisL5']
target_angles = [88, 92] # picks all angles between the two values
target_cells = ['e4', 'i4Pvalb', 'i4Sst', 'i4Htr3a', 'e5', 'i5Pvalb', 'i5Sst', 'i5Htr3a'] # e4 i4Pvalb i4Sst i4Htr3a e5 i5Pvalb i5Sst i5Htr3a
target_cells = ['e4']

df = df[df['location'].isin(target_layers)]
df = df[df['pop_name'].isin(target_cells)]
df = df[df['tuning_angle'] > target_angles[0]]
df = df[df['tuning_angle'] < target_angles[1]]

df
# Out:
#        node_id  node_type_id     dynamics_params   model_type  \
# 15935    74591     318733871  318733871_fit.json  biophysical
# 15936    74592     318733871  318733871_fit.json  biophysical
# 16100    74756     318808427  318808427_fit.json  biophysical
# 16101    74757     318808427  318808427_fit.json  biophysical
# 16102    74758     318808427  318808427_fit.json  biophysical
# ...        ...           ...                 ...          ...
# 25798   115718     485909730  485909730_fit.json  biophysical
# 25891   115811     486146717  486146717_fit.json  biophysical
# 25892   115812     486146717  486146717_fit.json  biophysical
# 25893   115813     486146717  486146717_fit.json  biophysical
# 25894   115814     486146717  486146717_fit.json  biophysical
#
#           model_template pop_name population  model_processing ei location  \
# 15935  ctdb:Biophys1.hoc       e4         v1  aibs_perisomatic  e    VisL4
# ...
